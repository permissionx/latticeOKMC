# %%
#import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("/mnt/c/Users/xuke/Desktop/run.log")
plt.plot(data.step, data.nSIA, label="SIA")
plt.plot(data.step, data.nVac, label="Vac")
plt.legend()
